# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(style="whitegrid")
sns.set_theme()

# %%
df = pd.read_csv('transcriptomics_fractions.csv', index_col='Unnamed: 0')
df1 = pd.read_csv('samples_transcriptomics.csv', index_col='Unnamed: 0')
df2 = pd.read_csv('Ecoli_gene_functional_annotations.csv', encoding = 'cp1252', index_col='Unnamed: 0')

# %%
df
# Out:
#             a1      a1_1        a2      a2_1        a3        a4      a4_1  \
# aaeA  0.000004  0.000004  0.000006  0.000005  0.000006  0.000007  0.000006
# aaeB  0.000003  0.000003  0.000005  0.000005  0.000005  0.000006  0.000005
# aaeR  0.000034  0.000047  0.000040  0.000038  0.000030  0.000041  0.000032
# aaeX  0.000010  0.000013  0.000017  0.000023  0.000022  0.000025  0.000023
# aas   0.000037  0.000029  0.000051  0.000052  0.000047  0.000045  0.000043
# ...        ...       ...       ...       ...       ...       ...       ...
# zraR  0.000006  0.000006  0.000006  0.000007  0.000005  0.000005  0.000005
# zraS  0.000003  0.000005  0.000004  0.000004  0.000004  0.000005  0.000004
# zupT  0.000065  0.000123  0.000109  0.000141  0.000144  0.000171  0.000188
# zur   0.000044  0.000106  0.000046  0.000081  0.000048  0.000051  0.000072
# zwf   0.000319  0.000334  0.000463  0.000404  0.000476  0.000588  0.000521
#
# ...

# %%
Alim = df.iloc[:,:7].T
Alim['Growth.rate']= list(df1['Growth.rate..1.h.'][:7])
Alim
# Out:
#           aaeA      aaeB      aaeR      aaeX       aas       aat      abgA  \
# a1    0.000004  0.000003  0.000034  0.000010  0.000037  0.000049  0.000001
# a1_1  0.000004  0.000003  0.000047  0.000013  0.000029  0.000067  0.000001
# a2    0.000006  0.000005  0.000040  0.000017  0.000051  0.000063  0.000001
# a2_1  0.000005  0.000005  0.000038  0.000023  0.000052  0.000073  0.000001
# a3    0.000006  0.000005  0.000030  0.000022  0.000047  0.000078  0.000002
# a4    0.000007  0.000006  0.000041  0.000025  0.000045  0.000087  0.000002
# a4_1  0.000006  0.000005  0.000032  0.000023  0.000043  0.000088  0.000003
#
#           abgB      abgR      abgT  ...      znuA      znuB      znuC  \
# a1    0.000002  0.000010  0.000002  ...  0.000058  0.000021  0.000039
# a1_1  0.000003  0.000007  0.000002  ...  0.000052  0.000024  0.000046
# a2    0.000004  0.000012  0.000003  ...  0.000060  0.000024  0.000040
# a2_1  0.000004  0.000014  0.000003  ...  0.000059  0.000036  0.000050
# ...

# %%
df_sorted = df2.sort_values(by='gene', ascending=True).reset_index(drop=True)
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3738 entries, 0 to 3737
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gene                      3720 non-null   object
#  1   locus                     3720 non-null   object
#  2   protein_len               3738 non-null   int64
#  3   gene.length..nt.          3720 non-null   float64
#  4   cog_functional_cat        3738 non-null   object
#  5   cog_name                  3738 non-null   object
#  6   top_cog_functional_cat    3738 non-null   object
#  7   functional_category_desc  3738 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 233.8+ KB

# %%
df_sorted1 = df2.dropna(subset=['gene']).sort_values(by='gene', ascending=True).reset_index(drop=True)
df_sorted1
# Out:
#       gene  locus  protein_len  gene.length..nt. cog_functional_cat  \
# 0     aaeA  b3241          310             933.0                  V
# 1     aaeB  b3240          655            1968.0                  S
# 2     aaeR  b3243          309             930.0                  K
# 3      aas  b2836          719            2160.0                  I
# 4      aas  b2836          719            2160.0                  I
# ...    ...    ...          ...               ...                ...
# 3715  zraR  b4004          441            1326.0                  T
# 3716  zraS  b4003          465            1398.0                  T
# 3717  zupT  b3040          257             774.0                  P
# 3718   zur  b4046          171             516.0                  P
# 3719   zwf  b1852          491            1476.0                  G
#
#                                                cog_name  \
# 0                 Multidrug resistance efflux pump EmrA
# ...

# %%
df3 = pd.read_csv('transcriptomics_fractions.csv')
df3.loc[:, ~df.T.duplicated()]
