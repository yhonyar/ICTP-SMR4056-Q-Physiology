# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(style="whitegrid")
sns.set_theme()

# %%
df = pd.read_csv('transcriptomics_fractions.csv')
#df.describe()
df
# Out:
#      Unnamed: 0        a1      a1_1        a2      a2_1        a3        a4  \
# 0          aaeA  0.000004  0.000004  0.000006  0.000005  0.000006  0.000007
# 1          aaeB  0.000003  0.000003  0.000005  0.000005  0.000005  0.000006
# 2          aaeR  0.000034  0.000047  0.000040  0.000038  0.000030  0.000041
# 3          aaeX  0.000010  0.000013  0.000017  0.000023  0.000022  0.000025
# 4           aas  0.000037  0.000029  0.000051  0.000052  0.000047  0.000045
# ...         ...       ...       ...       ...       ...       ...       ...
# 4337       zraR  0.000006  0.000006  0.000006  0.000007  0.000005  0.000005
# 4338       zraS  0.000003  0.000005  0.000004  0.000004  0.000004  0.000005
# 4339       zupT  0.000065  0.000123  0.000109  0.000141  0.000144  0.000171
# 4340        zur  0.000044  0.000106  0.000046  0.000081  0.000048  0.000051
# 4341        zwf  0.000319  0.000334  0.000463  0.000404  0.000476  0.000588
#
#           a4_1      c0_1        c1  ...      r0_1        r1      r1_1  \
# 0     0.000006  0.000004  0.000003  ...  0.000003  0.000004  0.000003
# 1     0.000005  0.000004  0.000002  ...  0.000003  0.000004  0.000004
# 2     0.000032  0.000043  0.000020  ...  0.000028  0.000032  0.000027
# 3     0.000023  0.000013  0.000006  ...  0.000017  0.000013  0.000012
# 4     0.000043  0.000032  0.000033  ...  0.000035  0.000027  0.000025
# ...        ...       ...       ...  ...       ...       ...       ...
# 4337  0.000005  0.000007  0.000007  ...  0.000007  0.000008  0.000008
# 4338  0.000004  0.000005  0.000007  ...  0.000005  0.000004  0.000003
# 4339  0.000188  0.000086  0.000055  ...  0.000095  0.000068  0.000056
# 4340  0.000072  0.000115  0.000044  ...  0.000099  0.000059  0.000055
# 4341  0.000521  0.000253  0.000234  ...  0.000225  0.000193  0.000159
#
#             r2      r2_1        r3      r3_1        r4      r4_1        r5
# 0     0.000005  0.000005  0.000004  0.000005  0.000005  0.000006  0.000005
# 1     0.000004  0.000005  0.000005  0.000006  0.000005  0.000006  0.000005
# 2     0.000032  0.000027  0.000028  0.000025  0.000031  0.000028  0.000032
# 3     0.000013  0.000010  0.000013  0.000011  0.000019  0.000015  0.000019
# 4     0.000024  0.000025  0.000026  0.000025  0.000024  0.000022  0.000023
# ...        ...       ...       ...       ...       ...       ...       ...
# 4337  0.000008  0.000008  0.000008  0.000010  0.000009  0.000009  0.000008
# 4338  0.000003  0.000003  0.000003  0.000004  0.000003  0.000004  0.000003
# 4339  0.000045  0.000052  0.000048  0.000053  0.000053  0.000050  0.000045
# 4340  0.000037  0.000033  0.000035  0.000032  0.000036  0.000034  0.000034
# 4341  0.000169  0.000131  0.000149  0.000116  0.000151  0.000120  0.000149
#
# [4342 rows x 29 columns]

# %%
# Select numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Create a list to store results
summary_list = []

# Extract required information
for y_column in numeric_columns:
    max_value = df[y_column].max()
    max_name = df[y_column].idxmax()  # Get the index (gene name) corresponding to max value
    #gene = df['Unnamed: 0']
    column_sum = df[y_column].sum()

    summary_list.append({
        #'Gene':gene,
        "Column": y_column,
        "Max Gene": max_name,
        "Max Value": max_value,
        "Sum": column_sum
    })

# Convert to DataFrame and display
summary_df = pd.DataFrame(summary_list)

summary_df
# Out:
#    Column  Max Gene  Max Value       Sum
# 0      a1      1468     0.0485  1.000014
# 1    a1_1      1468     0.0343  0.999912
# 2      a2      1468     0.0372  0.999963
# 3    a2_1       420     0.0269  0.999974
# 4      a3       420     0.0557  1.000058
# 5      a4      2302     0.0415  1.000037
# 6    a4_1       420     0.0379  0.999932
# 7    c0_1       420     0.0212  1.000040
# 8      c1      1468     0.0364  1.000035
# 9    c1_1       812     0.0347  0.999952
# 10     c2       812     0.0362  1.000062
# 11   c2_1       420     0.0445  0.999942
# 12     c3       812     0.0389  0.999874
# 13   c3_1       420     0.0342  0.999933
# 14     c4       420     0.0503  1.000190
# 15   c4_1       812     0.0375  0.999994
# 16     c5      1468     0.0274  1.000039
# 17     r0       420     0.0226  1.000020
# 18   r0_1       420     0.0550  0.999949
# 19     r1       416     0.0251  0.999986
# 20   r1_1       416     0.0421  1.000118
# 21     r2       416     0.0423  1.000019
# 22   r2_1       416     0.0492  1.000065
# 23     r3       416     0.0396  0.999783
# 24   r3_1       416     0.0540  0.999902
# 25     r4       416     0.0400  1.000096
# 26   r4_1       416     0.0483  0.999817
# 27     r5       416     0.0403  1.000121

# %%
column_names = df.select_dtypes(include=['number']).columns

max_rows_list = []

for col in column_names:
    max_index = df[col].idxmax()  
    max_row = df.loc[max_index]   
    max_rows_list.append(max_row)

max_rows_df = pd.concat(max_rows_list, axis=1)

max_rows_df
# Out:
#                1468     1468     1468     420      420       2302     420   \
# Unnamed: 0      lpp      lpp      lpp     cspE     cspE       rmf     cspE
# a1           0.0485   0.0485   0.0485   0.0194   0.0194   0.00161   0.0194
# a1_1         0.0343   0.0343   0.0343   0.0162   0.0162    0.0029   0.0162
# a2           0.0372   0.0372   0.0372   0.0255   0.0255   0.00676   0.0255
# a2_1         0.0185   0.0185   0.0185   0.0269   0.0269   0.00456   0.0269
# a3           0.0525   0.0525   0.0525   0.0557   0.0557    0.0227   0.0557
# a4           0.0312   0.0312   0.0312   0.0396   0.0396    0.0415   0.0396
# a4_1         0.0172   0.0172   0.0172   0.0379   0.0379     0.028   0.0379
# c0_1         0.0178   0.0178   0.0178   0.0212   0.0212  0.000755   0.0212
# c1           0.0364   0.0364   0.0364   0.0268   0.0268   0.00141   0.0268
# c1_1         0.0194   0.0194   0.0194    0.017    0.017   0.00256    0.017
# c2           0.0267   0.0267   0.0267   0.0312   0.0312   0.00161   0.0312
# c2_1         0.0196   0.0196   0.0196   0.0445   0.0445   0.00295   0.0445
# c3           0.0307   0.0307   0.0307   0.0362   0.0362   0.00316   0.0362
# c3_1         0.0147   0.0147   0.0147   0.0342   0.0342   0.00425   0.0342
# c4           0.0274   0.0274   0.0274   0.0503   0.0503    0.0106   0.0503
# c4_1         0.0145   0.0145   0.0145   0.0351   0.0351   0.00705   0.0351
# c5           0.0274   0.0274   0.0274   0.0146   0.0146  0.000554   0.0146
# r0          0.00708  0.00708  0.00708   0.0226   0.0226  0.000459   0.0226
# r0_1         0.0391   0.0391   0.0391    0.055    0.055   0.00144    0.055
# r1          0.00727  0.00727  0.00727   0.0143   0.0143  0.000326   0.0143
# r1_1         0.0174   0.0174   0.0174    0.016    0.016  0.000403    0.016
# r2            0.005    0.005    0.005  0.00819  0.00819  0.000209  0.00819
# r2_1         0.0177   0.0177   0.0177  0.00967  0.00967  0.000334  0.00967
# r3          0.00678  0.00678  0.00678  0.00699  0.00699  0.000205  0.00699
# r3_1          0.019    0.019    0.019  0.00584  0.00584  0.000344  0.00584
# r4           0.0066   0.0066   0.0066   0.0056   0.0056  0.000212   0.0056
# r4_1         0.0143   0.0143   0.0143  0.00362  0.00362  0.000285  0.00362
# r5          0.00746  0.00746  0.00746   0.0056   0.0056  0.000223   0.0056
#
#                420      1468      812   ...     420      416      416   \
# Unnamed: 0     cspE      lpp      fliC  ...     cspE     cspA     cspA
# a1           0.0194   0.0485   0.00984  ...   0.0194    0.013    0.013
# a1_1         0.0162   0.0343   0.00964  ...   0.0162  0.00605  0.00605
# a2           0.0255   0.0372  0.000127  ...   0.0255   0.0152   0.0152
# a2_1         0.0269   0.0185  0.000113  ...   0.0269   0.0101   0.0101
# a3           0.0557   0.0525  0.000074  ...   0.0557   0.0122   0.0122
# a4           0.0396   0.0312  0.000271  ...   0.0396   0.0152   0.0152
# a4_1         0.0379   0.0172  0.000117  ...   0.0379   0.0124   0.0124
# c0_1         0.0212   0.0178    0.0132  ...   0.0212   0.0146   0.0146
# c1           0.0268   0.0364    0.0231  ...   0.0268   0.0181   0.0181
# c1_1          0.017   0.0194    0.0347  ...    0.017  0.00561  0.00561
# c2           0.0312   0.0267    0.0362  ...   0.0312   0.0174   0.0174
# c2_1         0.0445   0.0196    0.0356  ...   0.0445   0.0144   0.0144
# c3           0.0362   0.0307    0.0389  ...   0.0362   0.0202   0.0202
# c3_1         0.0342   0.0147     0.031  ...   0.0342   0.0116   0.0116
# c4           0.0503   0.0274    0.0374  ...   0.0503   0.0133   0.0133
# c4_1         0.0351   0.0145    0.0375  ...   0.0351  0.00941  0.00941
# c5           0.0146   0.0274    0.0183  ...   0.0146   0.0171   0.0171
# r0           0.0226  0.00708    0.0222  ...   0.0226   0.0131   0.0131
# r0_1          0.055   0.0391    0.0217  ...    0.055   0.0245   0.0245
# r1           0.0143  0.00727    0.0155  ...   0.0143   0.0251   0.0251
# r1_1          0.016   0.0174   0.00854  ...    0.016   0.0421   0.0421
# r2          0.00819    0.005   0.00645  ...  0.00819   0.0423   0.0423
# r2_1        0.00967   0.0177   0.00221  ...  0.00967   0.0492   0.0492
# r3          0.00699  0.00678   0.00446  ...  0.00699   0.0396   0.0396
# r3_1        0.00584    0.019  0.000283  ...  0.00584    0.054    0.054
# r4           0.0056   0.0066   0.00211  ...   0.0056     0.04     0.04
# r4_1        0.00362   0.0143  0.000068  ...  0.00362   0.0483   0.0483
# r5           0.0056  0.00746   0.00185  ...   0.0056   0.0403   0.0403
#
#                416      416      416      416      416      416      416
# Unnamed: 0     cspA     cspA     cspA     cspA     cspA     cspA     cspA
# a1            0.013    0.013    0.013    0.013    0.013    0.013    0.013
# a1_1        0.00605  0.00605  0.00605  0.00605  0.00605  0.00605  0.00605
# a2           0.0152   0.0152   0.0152   0.0152   0.0152   0.0152   0.0152
# a2_1         0.0101   0.0101   0.0101   0.0101   0.0101   0.0101   0.0101
# a3           0.0122   0.0122   0.0122   0.0122   0.0122   0.0122   0.0122
# a4           0.0152   0.0152   0.0152   0.0152   0.0152   0.0152   0.0152
# a4_1         0.0124   0.0124   0.0124   0.0124   0.0124   0.0124   0.0124
# c0_1         0.0146   0.0146   0.0146   0.0146   0.0146   0.0146   0.0146
# c1           0.0181   0.0181   0.0181   0.0181   0.0181   0.0181   0.0181
# c1_1        0.00561  0.00561  0.00561  0.00561  0.00561  0.00561  0.00561
# c2           0.0174   0.0174   0.0174   0.0174   0.0174   0.0174   0.0174
# c2_1         0.0144   0.0144   0.0144   0.0144   0.0144   0.0144   0.0144
# c3           0.0202   0.0202   0.0202   0.0202   0.0202   0.0202   0.0202
# c3_1         0.0116   0.0116   0.0116   0.0116   0.0116   0.0116   0.0116
# c4           0.0133   0.0133   0.0133   0.0133   0.0133   0.0133   0.0133
# c4_1        0.00941  0.00941  0.00941  0.00941  0.00941  0.00941  0.00941
# c5           0.0171   0.0171   0.0171   0.0171   0.0171   0.0171   0.0171
# r0           0.0131   0.0131   0.0131   0.0131   0.0131   0.0131   0.0131
# r0_1         0.0245   0.0245   0.0245   0.0245   0.0245   0.0245   0.0245
# r1           0.0251   0.0251   0.0251   0.0251   0.0251   0.0251   0.0251
# r1_1         0.0421   0.0421   0.0421   0.0421   0.0421   0.0421   0.0421
# r2           0.0423   0.0423   0.0423   0.0423   0.0423   0.0423   0.0423
# r2_1         0.0492   0.0492   0.0492   0.0492   0.0492   0.0492   0.0492
# r3           0.0396   0.0396   0.0396   0.0396   0.0396   0.0396   0.0396
# r3_1          0.054    0.054    0.054    0.054    0.054    0.054    0.054
# r4             0.04     0.04     0.04     0.04     0.04     0.04     0.04
# r4_1         0.0483   0.0483   0.0483   0.0483   0.0483   0.0483   0.0483
# r5           0.0403   0.0403   0.0403   0.0403   0.0403   0.0403   0.0403
#
# [29 rows x 28 columns]

# %%
#max_rows_df.iloc[:, 0]
lpp_ordenado = max_rows_df.iloc[1:, 1:2]#.sort_values(by=1468, ascending=True)
lpp_ordenado.columns = ['lpp']
df_reset = lpp_ordenado.reset_index(drop=True)
df_reset
# Out:
#         lpp
# 0    0.0485
# 1    0.0343
# 2    0.0372
# 3    0.0185
# 4    0.0525
# 5    0.0312
# 6    0.0172
# 7    0.0178
# 8    0.0364
# 9    0.0194
# 10   0.0267
# 11   0.0196
# 12   0.0307
# 13   0.0147
# 14   0.0274
# 15   0.0145
# 16   0.0274
# 17  0.00708
# 18   0.0391
# 19  0.00727
# 20   0.0174
# 21    0.005
# 22   0.0177
# 23  0.00678
# 24    0.019
# 25   0.0066
# 26   0.0143
# 27  0.00746

# %%
df5 = df1[['Sample.ID','Growth.rate..1.h.']]
df5
# Out:
#    Sample.ID  Growth.rate..1.h.
# 0         a1               0.69
# 1       a1_1               0.76
# 2         a2               0.51
# 3       a2_1               0.55
# 4         a3               0.33
# 5         a4               0.24
# 6       a4_1               0.34
# 7       c0_1               0.95
# 8         c1               0.75
# 9       c1_1               0.78
# 10        c2               0.56
# 11      c2_1               0.59
# 12        c3               0.51
# 13      c3_1               0.46
# 14        c4               0.30
# 15      c4_1               0.39
# 16        c5               0.91
# 17        r0               0.89
# 18      r0_1               0.91
# 19        r1               0.71
# 20      r1_1               0.61
# 21        r2               0.53
# 22      r2_1               0.44
# 23        r3               0.45
# 24      r3_1               0.35
# 25        r4               0.40
# 26      r4_1               0.28
# 27        r5               0.38

# %%
df_combined = pd.concat([df5, df_reset], axis=1)
df_combined
# Out:
#    Sample.ID  Growth.rate..1.h.      lpp
# 0         a1               0.69   0.0485
# 1       a1_1               0.76   0.0343
# 2         a2               0.51   0.0372
# 3       a2_1               0.55   0.0185
# 4         a3               0.33   0.0525
# 5         a4               0.24   0.0312
# 6       a4_1               0.34   0.0172
# 7       c0_1               0.95   0.0178
# 8         c1               0.75   0.0364
# 9       c1_1               0.78   0.0194
# 10        c2               0.56   0.0267
# 11      c2_1               0.59   0.0196
# 12        c3               0.51   0.0307
# 13      c3_1               0.46   0.0147
# 14        c4               0.30   0.0274
# 15      c4_1               0.39   0.0145
# 16        c5               0.91   0.0274
# 17        r0               0.89  0.00708
# 18      r0_1               0.91   0.0391
# 19        r1               0.71  0.00727
# 20      r1_1               0.61   0.0174
# 21        r2               0.53    0.005
# 22      r2_1               0.44   0.0177
# 23        r3               0.45  0.00678
# 24      r3_1               0.35    0.019
# 25        r4               0.40   0.0066
# 26      r4_1               0.28   0.0143
# 27        r5               0.38  0.00746

# %%
df6 = df_combined.sort_values(by='Growth.rate..1.h.', ascending = True)

# %%
plt.figure(figsize=(6, 4))
sns.lineplot(x=df6['Growth.rate..1.h.'], y=df6['lpp'], marker='o')
plt.title('')
plt.xlabel('Growth rate')
plt.ylabel('Abundance')
# Out:
# Text(0, 0.5, 'Abundance')

# %%
df['a1'].max()

# %%
max_values = df.max()
fila_max = df.idxmax()

# %%
cols_per_figure = 4 

for i in range(1, df.shape[1], cols_per_figure):
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 3))
    axes = axes.flatten()  
    
    for j, col in enumerate(df.columns[i:i+cols_per_figure]):
        ax = axes[j]
        sns.lineplot(x=df.index, y=df[col], ax=ax, marker='o')
        ax.set_title(f'{col}')
        #ax.set_xlabel('')
        ax.set_ylabel('Conc.')
    
    plt.tight_layout()
    plt.show()

# %%
df1 = pd.read_csv('samples_transcriptomics.csv')

# %%
df1
# Out:
#     Unnamed: 0 Sample.ID Group  Growth.rate..1.h.   Strain Growth.medium  \
# 0           11        a1  Alim               0.69    NQ393            M9
# 1           15      a1_1  Alim               0.76    NQ393            M9
# 2           12        a2  Alim               0.51    NQ393            M9
# 3           16      a2_1  Alim               0.55    NQ393            M9
# 4           13        a3  Alim               0.33    NQ393            M9
# 5           14        a4  Alim               0.24    NQ393            M9
# 6           18      a4_1  Alim               0.34    NQ393            M9
# 7            6      c0_1  Clim               0.95  NCM3722            M9
# 8            2        c1  Clim               0.75   NQ1243            M9
# 9            7      c1_1  Clim               0.78   NQ1243            M9
# 10           3        c2  Clim               0.56   NQ1243            M9
# 11           8      c2_1  Clim               0.59   NQ1243            M9
# 12           4        c3  Clim               0.51   NQ1390            M9
# 13           9      c3_1  Clim               0.46   NQ1390            M9
# 14           5        c4  Clim               0.30   NQ1390            M9
# 15          10      c4_1  Clim               0.39   NQ1390            M9
# 16           1        c5  Clim               0.91  NCM3722            M9
# 17          19        r0  Rlim               0.89  NCM3722          MOPS
# 18          25      r0_1  Rlim               0.91  NCM3722          MOPS
# 19          20        r1  Rlim               0.71  NCM3722          MOPS
# 20          26      r1_1  Rlim               0.61  NCM3722          MOPS
# 21          21        r2  Rlim               0.53  NCM3722          MOPS
# 22          27      r2_1  Rlim               0.44  NCM3722          MOPS
# 23          22        r3  Rlim               0.45  NCM3722          MOPS
# 24          28      r3_1  Rlim               0.35  NCM3722          MOPS
# 25          23        r4  Rlim               0.40  NCM3722          MOPS
# 26          29      r4_1  Rlim               0.28  NCM3722          MOPS
# 27          24        r5  Rlim               0.38  NCM3722          MOPS
#
#    Carbon.source     Nitrogen.source            Supplement  \
# 0   0.2% glucose  11.34 mM (NH4)2SO4            60 µM IPTG
# 1   0.2% glucose  11.34 mM (NH4)2SO4            60 µM IPTG
# 2   0.2% glucose  11.34 mM (NH4)2SO4            40 µM IPTG
# 3   0.2% glucose  11.34 mM (NH4)2SO5            40 µM IPTG
# 4   0.2% glucose  11.34 mM (NH4)2SO4            28 µM IPTG
# 5   0.2% glucose  11.34 mM (NH4)2SO4            20 µM IPTG
# 6   0.2% glucose  11.34 mM (NH4)2SO7            20 µM IPTG
# 7   0.2% glucose  11.34 mM (NH4)2SO4                   NaN
# 8   0.2% glucose  11.34 mM (NH4)2SO4           300 µM 3MBA
# 9   0.2% glucose  11.34 mM (NH4)2SO4           300 µM 3MBA
# 10  0.2% glucose  11.34 mM (NH4)2SO4                   NaN
# 11  0.2% glucose  11.34 mM (NH4)2SO4                   NaN
# 12  0.2% glucose  11.34 mM (NH4)2SO4           400 µM 3MBA
# 13  0.2% glucose  11.34 mM (NH4)2SO4           400 µM 3MBA
# 14  0.2% glucose  11.34 mM (NH4)2SO4            40 µM 3MBA
# 15  0.2% glucose  11.34 mM (NH4)2SO4            40 µM 3MBA
# 16  0.2% glucose  11.34 mM (NH4)2SO4                   NaN
# 17  0.2% glucose         10 mM NH4Cl                   NaN
# 18  0.2% glucose         10 mM NH4Cl                   NaN
# 19  0.2% glucose         10 mM NH4Cl  2 µM chloramphenicol
# 20  0.2% glucose         10 mM NH4Cl  2 µM chloramphenicol
# 21  0.2% glucose         10 mM NH4Cl  4 µM chloramphenicol
# 22  0.2% glucose         10 mM NH4Cl  4 µM chloramphenicol
# 23  0.2% glucose         10 mM NH4Cl  6 µM chloramphenicol
# 24  0.2% glucose         10 mM NH4Cl  6 µM chloramphenicol
# 25  0.2% glucose         10 mM NH4Cl  8 µM chloramphenicol
# 26  0.2% glucose         10 mM NH4Cl  8 µM chloramphenicol
# 27  0.2% glucose         10 mM NH4Cl  9 µM chloramphenicol
#
#                                      Description  \
# 0   Titratable ammonia assimilation (Plac-GOGAT)
# 1              Biological replicate of sample a1
# 2   Titratable ammonia assimilation (Plac-GOGAT)
# 3              Biological replicate of sample a2
# 4   Titratable ammonia assimilation (Plac-GOGAT)
# 5   Titratable ammonia assimilation (Plac-GOGAT)
# 6              Biological replicate of sample a4
# 7              Biological replicate of sample c5
# 8            Titratable glucose uptake (Pu-ptsG)
# 9              Biological replicate of sample c1
# 10           Titratable glucose uptake (Pu-ptsG)
# 11             Biological replicate of sample c2
# 12           Titratable glucose uptake (Pu-ptsG)
# 13             Biological replicate of sample c3
# 14           Titratable glucose uptake (Pu-ptsG)
# 15             Biological replicate of sample c4
# 16              NCM3722 (wild type) in M9 medium
# 17            NCM3722 (wild type) in MOPS medium
# 18             Biological replicate of sample r0
# 19     Cloramphenicol (translational) inhibition
# 20             Biological replicate of sample r1
# 21     Cloramphenicol (translational) inhibition
# 22             Biological replicate of sample r2
# 23     Cloramphenicol (translational) inhibition
# 24             Biological replicate of sample r3
# 25     Cloramphenicol (translational) inhibition
# 26             Biological replicate of sample r4
# 27     Cloramphenicol (translational) inhibition
#
#                         File.name
# 0   Rohan_A1_S6_L008_R1_001.fastq
# 1         A1_S6_L004_R1_001.fastq
# 2   Rohan_A2_S7_L008_R1_001.fastq
# 3         A2_S7_L004_R1_001.fastq
# 4   Rohan_A3_S8_L008_R1_001.fastq
# 5   Rohan_A4_S9_L008_R1_001.fastq
# 6         A4_S9_L004_R1_001.fastq
# 7         Rf_S1_L004_R1_001.fastq
# 8   Rohan_C1_S2_L008_R1_001.fastq
# 9         C1_S2_L004_R1_001.fastq
# 10  Rohan_C2_S3_L008_R1_001.fastq
# 11        C2_S3_L004_R1_001.fastq
# 12  Rohan_C3_S4_L008_R1_001.fastq
# 13        C3_S4_L004_R1_001.fastq
# 14  Rohan_C4_S5_L008_R1_001.fastq
# 15        C4_S5_L004_R1_001.fastq
# 16   Rohan_0_S1_L008_R1_001.fastq
# 17        R0_S9_L001_R1_001.fastq
# 18       R0_S10_L004_R1_001.fastq
# 19       R1_S10_L001_R1_001.fastq
# 20       R1_S11_L004_R1_001.fastq
# 21       R2_S11_L001_R1_001.fastq
# 22       R2_S12_L004_R1_001.fastq
# 23       R3_S12_L001_R1_001.fastq
# 24       R3_S13_L004_R1_001.fastq
# 25       R4_S13_L001_R1_001.fastq
# 26       R4_S14_L004_R1_001.fastq
# 27       R5_S14_L001_R1_001.fastq

# %%
#df_sorted = df1.sort_values(by='Unnamed: 0', ascending=True)
#df_sorted

# %%
groups = df1['Group'].unique()  

for group in groups:
    df1_filtrado = df1[df1['Group'] == group]
    
    plt.figure(figsize=(6, 4))
    #sns.lineplot(x=df1_filtrado['Growth.rate..1.h.'], y=df1_filtrado.index, marker='o')
    sns.barplot(x=df1_filtrado['Sample.ID'], y=df1_filtrado['Growth.rate..1.h.'])
    plt.title(f'{group}')
    plt.xlabel('')
    plt.ylabel('Growth rate')
    plt.show()

# %%
df2 = pd.read_csv('Ecoli_gene_functional_annotations.csv', encoding = 'cp1252')

df2

# %%
plt.figure(figsize=(6, 4))
sns.lineplot(x=df2['Unnamed: 0'], y=df2['protein_len'], marker='o')
#sns.barplot(x=df1_filtrado['Sample.ID'], y=df1_filtrado['Growth.rate..1.h.'])
plt.title('protein_len')
plt.xlabel('')
plt.ylabel('')

# %% [markdown]
# ## How does the abundance of transcripts (proteins) change with the growth rate?
